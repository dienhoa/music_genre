# %%
from fastai.vision.all import *
import torchaudio

# %%
df_train = pd.read_csv('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train.csv')
df_test = pd.read_csv('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/test.csv')
submission = pd.read_csv('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/sample_submission.csv')

# %%
# train_path = Path('/home/ubuntu/.kaggle/resampled/resampled_train/')
# test_path = Path('/home/ubuntu/.kaggle/resampled/resampled_test/')

train_path = Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/')
test_path = Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/test/')

# %%
train_files = get_files(train_path, extensions='.ogg')

# %%
train_files
# Out:
# (#19909) [Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/004391.ogg'),Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/004779.ogg'),Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/008428.ogg'),Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/014286.ogg'),Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/019471.ogg'),Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/005572.ogg'),Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/018065.ogg'),Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/008223.ogg'),Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/023818.ogg'),Path('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/train/021084.ogg')...]

# %%
train_files[0].stem
# Out:
# '004391'

# %%
def get_y(filename):
#     resample_name = filename.name.split('_')[0] + '.ogg'
    resample_name = filename.name
    return df_train[df_train['filename']==resample_name]['genre'].values[0]

# %%
get_y(train_files[0])
# Out:
# 'Electronic'

# %%
# excluded_files = ["010449_16k.wav" , 
#                   "005589_16k.wav" , 
#                   "004921_16k.wav", 
#                   "019511_16k.wav" , 
#                   "013375_16k.wav" , 
#                   "024247_16k.wav", 
#                   "024156_16k.wav"]

# %%
excluded_files = ["010449.ogg" , 
                  "005589.ogg" , 
                  "004921.ogg", 
                  "019511.ogg" , 
                  "013375.ogg" , 
                  "024247.ogg", 
                  "024156.ogg"]

# %%
# Excluded unusual music thanks to this thread: https://www.kaggle.com/c/kaggle-pog-series-s01e02/discussion/312842
def get_items(path): 

    items = get_files(path, extensions='.ogg')
    items = [item for item in items if item.name not in excluded_files]
    
    ## For fast iteration
#     items = [item for item in items if get_y(item) in ['Punk', 'Rock']]
    
#     items.shuffle()
    return L(items)

# %%
N_FFT = 2048
HOP_LEN = 512

# %%
filename = train_files[0]

# %%
filename.name.split('_')[0]
# Out:
# '004391.ogg'

# %%
def create_spectrogram(filename):
    audio, sr = torchaudio.load(filename)
    specgram = torchaudio.transforms.MelSpectrogram(sample_rate=sr, 
                                                    n_fft=N_FFT, 
                                                    win_length=N_FFT, 
                                                    hop_length=HOP_LEN*2,
                                                    center=True,
                                                    pad_mode="reflect",
                                                    power=2.0,
                                                    norm='slaney',
                                                    onesided=True,
                                                    n_mels=128,
                                                    mel_scale="htk"
                                                   )(audio).mean(axis=0)
    specgram = torchaudio.transforms.AmplitudeToDB()(specgram)
    specgram = specgram - specgram.min()
    specgram = specgram/specgram.max()*255
    
    
    return specgram

# %%
filename = train_files[0]
spec_default = create_spectrogram(filename)

# %%
spec_default.shape
# Out:
# torch.Size([128, 1291])

# %%
items = get_items(train_path)
labels = [get_y(item) for item in items]
Counter(labels)
# Out:
# Counter({'Electronic': 3071,
#          'Punk': 2581,
#          'International': 814,
#          'Folk': 1213,
#          'Rock': 3095,
#          'Chiptune / Glitch': 1180,
#          'Pop': 945,
#          'Instrumental': 1043,
#          'Experimental': 1799,
#          'Jazz': 306,
#          'Soul-RnB': 94,
#          'Hip-Hop': 1755,
#          'Old-Time / Historic': 408,
#          'Ambient Electronic': 796,
#          'Spoken': 94,
#          'Classical': 495,
#          'Country': 142,
#          'Blues': 58,
#          'Easy Listening': 13})

# %%
splitter = TrainTestSplitter(test_size=0.2, random_state=42, stratify=labels)

# %%
db = DataBlock(
    blocks=(ImageBlock, CategoryBlock),
    get_items=get_items,
    get_x=create_spectrogram,
    get_y=get_y,
    splitter=splitter,
    item_tfms=[Resize(128)],
    batch_tfms=aug_transforms(max_rotate=0, max_warp=0,size=128))

# %%
dls = db.dataloaders(train_path, bs=64)

# %%
dls.show_batch()

# %%
mixup = MixUp()

# %%
learn = cnn_learner(dls, 
                    xresnet50_deep, 
                    metrics=[accuracy, F1Score(average='micro')], 
                    pretrained=False, 
                    loss_func=LabelSmoothingCrossEntropy(), 
                    opt_func=ranger, 
                   )

# %%
learn.to_fp16()

# %%
## This is to make model works with 1-channel input
def alter_learner(learn, channels=1):
    learn.model[0][0][0].in_channels=channels
    learn.model[0][0][0].weight = torch.nn.parameter.Parameter(learn.model[0][0][0].weight[:,1,:,:].unsqueeze(1))

# %%
nchannels = 1
alter_learner(learn, nchannels)

# %%
learn.lr_find()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='0' class='' max='1' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
#
#
#     <div>
#       <progress value='0' class='' max='248' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/248 00:00<00:00]
#     </div>

# %%
learn.fit_flat_cos(32, 0.003, cbs=[mixup, CSVLogger()])
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>f1_score</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>2.867491</td>
#       <td>3.011837</td>
#       <td>0.247928</td>
#       <td>0.247928</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.500746</td>
#       <td>2.156174</td>
#       <td>0.365486</td>
#       <td>0.365486</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.375196</td>
#       <td>2.234909</td>
#       <td>0.387340</td>
#       <td>0.387340</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.269184</td>
#       <td>2.367720</td>
#       <td>0.370761</td>
#       <td>0.370761</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.236766</td>
#       <td>2.009798</td>
#       <td>0.418990</td>
#       <td>0.418990</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>2.183493</td>
#       <td>1.950620</td>
#       <td>0.451143</td>
#       <td>0.451143</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>2.179478</td>
#       <td>2.007639</td>
#       <td>0.413464</td>
#       <td>0.413464</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>2.146596</td>
#       <td>1.920014</td>
#       <td>0.455916</td>
#       <td>0.455916</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>2.144594</td>
#       <td>1.942702</td>
#       <td>0.446873</td>
#       <td>0.446873</td>
#       <td>02:18</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>2.122545</td>
#       <td>1.947456</td>
#       <td>0.440090</td>
#       <td>0.440090</td>
#       <td>02:19</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>2.099592</td>
#       <td>1.853719</td>
#       <td>0.482793</td>
#       <td>0.482793</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>2.100748</td>
#       <td>1.972930</td>
#       <td>0.438834</td>
#       <td>0.438834</td>
#       <td>02:20</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>2.086988</td>
#       <td>2.014241</td>
#       <td>0.412459</td>
#       <td>0.412459</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>2.060358</td>
#       <td>1.823959</td>
#       <td>0.494599</td>
#       <td>0.494599</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>2.073615</td>
#       <td>1.823560</td>
#       <td>0.488320</td>
#       <td>0.488320</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>2.068907</td>
#       <td>1.915468</td>
#       <td>0.458428</td>
#       <td>0.458428</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>2.046979</td>
#       <td>1.804111</td>
#       <td>0.491334</td>
#       <td>0.491334</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>2.035465</td>
#       <td>1.823261</td>
#       <td>0.491334</td>
#       <td>0.491334</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>2.052718</td>
#       <td>1.935455</td>
#       <td>0.439588</td>
#       <td>0.439588</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>2.022219</td>
#       <td>1.777900</td>
#       <td>0.516453</td>
#       <td>0.516453</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.008495</td>
#       <td>1.812000</td>
#       <td>0.500628</td>
#       <td>0.500628</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>2.002865</td>
#       <td>1.824896</td>
#       <td>0.490580</td>
#       <td>0.490580</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>2.007107</td>
#       <td>1.782235</td>
#       <td>0.511680</td>
#       <td>0.511680</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>2.002983</td>
#       <td>1.815153</td>
#       <td>0.495855</td>
#       <td>0.495855</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>1.977831</td>
#       <td>1.843565</td>
#       <td>0.485305</td>
#       <td>0.485305</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>1.970161</td>
#       <td>1.731602</td>
#       <td>0.531525</td>
#       <td>0.531525</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>1.953510</td>
#       <td>1.768910</td>
#       <td>0.516453</td>
#       <td>0.516453</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>1.940787</td>
#       <td>1.722747</td>
#       <td>0.536297</td>
#       <td>0.536297</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>1.921900</td>
#       <td>1.704833</td>
#       <td>0.544084</td>
#       <td>0.544084</td>
#       <td>02:24</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>1.914540</td>
#       <td>1.695065</td>
#       <td>0.548606</td>
#       <td>0.548606</td>
#       <td>02:21</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>1.890811</td>
#       <td>1.688221</td>
#       <td>0.548606</td>
#       <td>0.548606</td>
#       <td>02:22</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>1.883378</td>
#       <td>1.688545</td>
#       <td>0.549108</td>
#       <td>0.549108</td>
#       <td>02:20</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_loss()

# %%
interp = ClassificationInterpretation.from_learner(learn)
losses,idxs = interp.top_losses()
len(dls.valid_ds)==len(losses)==len(idxs)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# True

# %%
interp.plot_confusion_matrix(figsize=(7,7))

# %%
def genreid_from_genre(genre):
    return int(genre2id[genre2id['genre'] == genre]['genre_id'].values[0])

# %%
filename.name.split('_')[0]
# Out:
# '018663'

# %%
test_items = get_items(test_path)
test_dl = dls.test_dl(test_items)
preds = learn.get_preds(dl=test_dl)
preds_idx = preds[0].argmax(axis=1)
genre2id = pd.read_csv('/home/ubuntu/.kaggle/kaggle-pog-series-s01e02/genres.csv')
songid_preds = {int(file_path.name.split('_')[0]):genreid_from_genre(learn.dls.vocab[_id]) for file_path, _id in zip(test_items,preds_idx)}
submission['genre_id'] = submission['song_id'].map(songid_preds)
submission['genre_id'].fillna(0, inplace=True)
submission.genre_id = submission.genre_id.astype(int)
submission.to_csv(f"submission_{int(time.time())}.csv", index=False)
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
